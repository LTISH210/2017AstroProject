# %%
cd Desktop
# Out:
# /Users/astrocomnyc/Desktop

# %%
# %run importSim
# Out:
# yt : [INFO     ] 2017-06-17 14:43:53,854 Calculating time from 1.000e+00 to be 4.355e+17 seconds
# yt : [INFO     ] 2017-06-17 14:43:53,856 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2017-06-17 14:43:53,884 Parameters: current_time              = 4.35455710881e+17 s
# yt : [INFO     ] 2017-06-17 14:43:53,886 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2017-06-17 14:43:53,889 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-17 14:43:53,890 Parameters: domain_right_edge         = [ 60000.  60000.  60000.]
# yt : [INFO     ] 2017-06-17 14:43:53,893 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2017-06-17 14:43:53,897 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2017-06-17 14:43:53,899 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2017-06-17 14:43:53,901 Parameters: omega_matter              = 0.272
# ...

# %%
import finalFunction

# %%
reload(finalFunction)
# Out:
# <module 'finalFunction' from 'finalFunction.py'>

# %%
finalFunction.finalFunction(ds)
# Out:
# yt : [INFO     ] 2017-06-17 14:56:55,102 Projection completed
# YTQuadTreeProj (snapshot_600): , axis=0, field=[('gas', 'H_number_density')], weight_field=None
# yt : [INFO     ] 2017-06-17 14:56:55,106 Making a fixed resolution buffer of (('gas', 'H_number_density')) 512 by 512
# [[  1.32241403e+14   1.32241403e+14   1.32241403e+14 ...,   1.44301289e+14
#     1.44301289e+14   1.44301289e+14]
#  [  1.32241403e+14   1.32241403e+14   1.32241403e+14 ...,   1.44301289e+14
#     1.44301289e+14   1.44301289e+14]
#  [  1.32241403e+14   1.32241403e+14   1.32241403e+14 ...,   1.44301289e+14
#     1.44301289e+14   1.44301289e+14]
#  ...,
#  [  2.16292879e+18   2.16292879e+18   2.16292879e+18 ...,   1.02254706e+14
#     1.02254706e+14   1.02254706e+14]
#  [  2.16292879e+18   2.16292879e+18   2.16292879e+18 ...,   1.02254706e+14
#     1.02254706e+14   1.02254706e+14]
#  [  2.16292879e+18   2.16292879e+18   2.16292879e+18 ...,   1.02254706e+14
#     1.02254706e+14   1.02254706e+14]] cm**(-2)
# ...

# %%
finalFunction.finalFunction(ds, axis=1,coord="x")
# Out:
# yt : [INFO     ] 2017-06-17 14:57:37,840 Projection completed
# YTQuadTreeProj (snapshot_600): , axis=1, field=[('gas', 'H_number_density')], weight_field=None
# yt : [INFO     ] 2017-06-17 14:57:37,844 Making a fixed resolution buffer of (('gas', 'H_number_density')) 512 by 512
# [[  1.53494964e+14   1.53494964e+14   1.53494964e+14 ...,   3.24189853e+15
#     3.24189853e+15   3.24189853e+15]
#  [  1.53494964e+14   1.53494964e+14   1.53494964e+14 ...,   3.24189853e+15
#     3.24189853e+15   3.24189853e+15]
#  [  1.53494964e+14   1.53494964e+14   1.53494964e+14 ...,   3.24189853e+15
#     3.24189853e+15   3.24189853e+15]
#  ...,
#  [  1.87797753e+15   1.87797753e+15   1.87797753e+15 ...,   3.09624121e+14
#     3.09624121e+14   3.09624121e+14]
#  [  1.87797753e+15   1.87797753e+15   1.87797753e+15 ...,   3.09624121e+14
#     3.09624120e+14   3.09624120e+14]
#  [  1.87797753e+15   1.87797753e+15   1.87797753e+15 ...,   3.09624121e+14
#     3.09624120e+14   3.09624120e+14]] cm**(-2)
# ...

# %%
finalFunction.finalFunction(ds, axis=2, coord="z")
# Out:
# yt : [INFO     ] 2017-06-17 14:58:19,739 Projection completed
# YTQuadTreeProj (snapshot_600): , axis=2, field=[('gas', 'H_number_density')], weight_field=None
# yt : [INFO     ] 2017-06-17 14:58:19,743 Making a fixed resolution buffer of (('gas', 'H_number_density')) 512 by 512
# [[  2.32183911e+14   2.32183911e+14   2.32183911e+14 ...,   1.92211277e+14
#     1.92211277e+14   1.92211277e+14]
#  [  2.32183911e+14   2.32183911e+14   2.32183911e+14 ...,   1.92211277e+14
#     1.92211277e+14   1.92211277e+14]
#  [  2.32183911e+14   2.32183911e+14   2.32183911e+14 ...,   1.92211277e+14
#     1.92211277e+14   1.92211277e+14]
#  ...,
#  [  1.25542970e+14   1.25542970e+14   1.25542970e+14 ...,   1.19126419e+14
#     1.19126419e+14   1.19126419e+14]
#  [  1.25542970e+14   1.25542970e+14   1.25542970e+14 ...,   1.19126419e+14
#     1.19126419e+14   1.19126419e+14]
#  [  1.25542970e+14   1.25542970e+14   1.25542970e+14 ...,   1.19126419e+14
#     1.19126419e+14   1.19126419e+14]] cm**(-2)
# ...
